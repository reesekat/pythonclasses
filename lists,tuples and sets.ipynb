# %%
#lists
marks1=35
marks2=45
marks3=65
marks4=45
marks5=87

students=[35,45,65,45,87]  #can store same datatype data
print(type(students))
students1=[36,'mango',34.7,True] #can store multiple datatype data #heterogenous
print(type(students1))
# Out:
# <class 'list'>
# <class 'list'>

# %%
#string into list
list2=list("this is a list")
print(list2)
print(type(list2))
# Out:
# ['t', 'h', 'i', 's', ' ', 'i', 's', ' ', 'a', ' ', 'l', 'i', 's', 't']
# <class 'list'>

# %%
#repeating list
list3=[1]*5
print(list3)
# Out:
# [1, 1, 1, 1, 1]

# %%
#indexing in lists
fruits=['banana','mango','strawberry']
print(fruits[0])
print(fruits[-1])
# Out:
# banana
# strawberry

# %%
#slicing in lists
#[start:stop:step]
fruits=['banana','mango','strawberry','grapes','orange']
print(fruits[1:3])
print(fruits[0:2])
print(fruits[-4:-1])
print(fruits[0:3:2])
print(fruits[::-1])  #reverse a list
# Out:
# ['mango', 'strawberry']
# ['banana', 'mango']
# ['mango', 'strawberry', 'grapes']
# ['banana', 'strawberry']
# ['orange', 'grapes', 'strawberry', 'mango', 'banana']

# %%
#lists are mutable in nature
list2=[10,20,30,40]
list2[0]=100
print(list2)
# Out:
# [100, 20, 30, 40]

# %%
#list methods- .append, .insert , .remove, .pop
list2=[10,20,30,40]  
list2.append(50)   #append is adding a value to the end of the list
print(list2)

list2=[10,20,30,40]  
list2.append([50,60,70]) 
print(list2)

list2.insert(1,35)  #insert is to add a value using index position
print(list2)
list2.remove(35)  #exact value to be removed from the list
print(list2)
list2.pop()  #by default removes the last value
print(list2)
list2.pop(1) #removing element using index position
print(list2)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, [50, 60, 70]]
# [10, 35, 20, 30, 40, [50, 60, 70]]
# [10, 20, 30, 40, [50, 60, 70]]
# [10, 20, 30, 40]
# [10, 30, 40]

# %%
a=[1,2,3]
b=[4,5,6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
marks=[78,102,96]
marks.sort()  #sorts the list
print(marks)
marks=[45,89,21]
marks.reverse() #reverses the list
print(marks)
marks.clear() #remove everything
print(marks)
# Out:
# [78, 96, 102]
# [21, 89, 45]
# []

# %%
nums=[10,60,78,89]
print(nums.index(78))  #gives position of item
nums2=[1,2,3,3,2,2,"banana","banana"]
print(nums2.count("banana"))   #count occurrences
a=[1,2,3]
b=a.copy()         #creating a shallow copy
print(b)
print(len(nums2))    #length of list
# Out:
# 2
# 2
# [1, 2, 3]
# 8

# %%
#deepcopy -full copy, for deepcopy we import copy module because it's not a inbuilt method

import copy
a=[[1,2],[3,4]]
b=copy.deepcopy(a)
b[0][0]=100
print(a)
print(b)
# Out:
# [[1, 2], [3, 4]]
# [[100, 2], [3, 4]]

# %%
#Tuples - used when you need data safety,fixed records

nums=(10,20,30)  #packing a tuple
print(nums[0]) #accessing a tuple element using index (unpacking a tuple)
# Out:
# 10

# %%
#slicing in tuples

nums=(10,20,30,40)

print(nums[1:4])
print(nums[:3])
# Out:
# (20, 30, 40)
# (10, 20, 30)

# %%
#tuple methods
nums=(1,2,4,3,2,3,3)
print(nums.count(2)) #count
print(nums.index(3)) #prints first index of the value
# Out:
# 2
# 3

# %%
#built in functions that can be used against tuples
nums=(10,20,30)
print(len(nums))
print(max(nums))
print(min(nums))
print(sum(nums))
# Out:
# 3
# 30
# 10
# 60

# %%
#Sets

numbers={10,20,40,20,10}
print(numbers)
print(type(numbers))
# Out:
# {40, 10, 20}
# <class 'set'>

# %%
numbers=set([1,2,3,4])
print(numbers)
print(type(numbers))
# Out:
# {1, 2, 3, 4}
# <class 'set'>

# %%
numbers=set("white")
print(numbers)
print(type(numbers))
# Out:
# {'w', 'e', 'i', 't', 'h'}
# <class 'set'>

# %%
#set methods
#adding elements
colors=set(["red","green","blue"])
colors.add("yellow")
print(colors)
colors.update(["black","white"])
print(colors)
# Out:
# {'green', 'yellow', 'red', 'blue'}
# {'green', 'red', 'blue', 'black', 'yellow', 'white'}

# %%
#removes duplicates
a=[1,2,3,3,4,4,5]
b=set(a)
print(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
colors.remove("blue")
print(colors)
# Out:
# {'green', 'red', 'black', 'yellow', 'white'}

# %%
#removing elements

print(colors)
colors.pop()
print(colors)
colors.clear()    #removing all elements
print(colors)
# Out:
# {'white', 'black', 'green', 'red', 'yellow'}
# {'black', 'green', 'red', 'yellow'}
# set()

# %% [markdown]
# Method	              Meaning	                      Example	                 Output
# union()	            Combines elements from both	        A.union(B)	         {1,2,3,4,5,6,7,8}
# intersection()	       Common elements	                A.intersection(B)	      {4,5}
# difference()	       Elements only in A	            A.difference(B)	         {1,2,3}
# symmetric_difference()	Elements not in both	     A.symmetric_difference(B)	{1,2,3,6,7,8}
# update()	        Adds items from another set to A	 A.update(B)	        modifies A
# difference_update()	Removes common elements	         A.difference_update(B)	    modifies A
# issubset()	         True if all of A in B	           {1,2}.issubset(A)	      True
# issuperset()	    True if A contains all of B	         A.issuperset({1,2})	  True
# isdisjoint()	     True if no common elements	        {9,10}.isdisjoint(A)	  True

# %%
#set operations-

a={1,2,3}
b={4,5,6}
#union
#a | b
print(a.union(b))   #union gives all unique elements
#intersection
#a & b
print(a.intersection(b))  #common elements
#a-b
print(a.difference(b))
#symmetric difference        #elements in A not in B
#a^b
print(a.symmetric_difference(b))  #elements in either but not both

print(a.difference_update(b))  #Removes common elements

A={2,3}
B={2,3,4,1,5}
print(A.issubset(B))    #True if all of A in B
print(B.issuperset(A))   #True if B contains all of A	
print(A.isdisjoint(a))   #True if no common elements
# Out:
# {1, 2, 3, 4, 5, 6}
# set()
# {1, 2, 3}
# {1, 2, 3, 4, 5, 6}
# None
# True
# True
# False

# %%
#Dictionaries-

student={"name":"Alex","age":22,"marks":85}
print(student["age"])  #calling/accessing data through key instead of index
# Out:
# 22

# %%
#dictionary methods
#adding/updating a dictionary

student["city"]="Bangalore"
student["Age"]=23
student["name"]="New_name"
print(student)

#removing items

student.pop("marks")  #remove key
student.popitem()      #remove last item
del student["age"]
print(student)
# Out:
# {'name': 'New_name', 'age': 22, 'marks': 85, 'city': 'Bangalore', 'Age': 23}
# {'name': 'New_name', 'city': 'Bangalore'}

# %%
#keys and values
print(student.keys()) #gives only keys
print(student.values()) #give only values
print(student.items())  #entire dictionary
# Out:
# dict_keys(['name', 'city'])
# dict_values(['New_name', 'Bangalore'])
# dict_items([('name', 'New_name'), ('city', 'Bangalore')])

# %%
#other common methods
student.update({"marks":90,"city":"Hyderabad"})
print(student)
backup= student.copy()
print(backup)
student.clear()
print(student)
# Out:
# {'marks': 90, 'city': 'Hyderabad'}
# {'marks': 90, 'city': 'Hyderabad'}
# {}

# %%
#nested dictionaries

#dictionary inside a dictionary

employee={"id":101,"details":{"name":"John","age":45,"salary":67000}}
print(employee["details"]["salary"])
# Out:
# 67000

# %%
#list of dictionaries
students=[{"name":"Alex","marks":85},{"name":"Sam","marks":90}]
print(students[1]["name"])
# Out:
# Sam

# %% [markdown]
# Feature          List      Tuple    Set    Dictionary
#
# ordered          yes        yes     no       yes
# mutable          yes        no      yes      yes
# key-value        no         no      no       yes
# duplicates       yes        yes     no       keys-no

# %% [markdown]
# BITWISE OPERATORS
#
# binary and &     -  both bits if 1 = 1
# binary or  |     - either bits must be 1
# binary xor ^     - either one of the bits only must be one
# negation   ~     - if the bit is one then output is 0 and if bit is 0 then output is 1
# left shift <<    - shifting towards left and adding zeros at the right
# right shift >>   - shifting towards right and dropping bits

# %% [markdown]
# bitwise &  -- T & T --> T
#               T & F --> F
#               F & T --> F
#               F & F --> F
#
#
# bitwise |  -- T | T --> T
#               T | F --> T
#               F | T --> T
#               F | F --> F
#
# bitwise ^  -- T ^ T --> F
#               T ^ F --> T
#               F ^ T --> T
#               F ^ F --> F
#
# negation ~  --> ~x=-(x+1)  2's complement formula

# %%
print(5&3)      
print(5|3)
print(5^3)
print(~5)
print(5<<1)
print(5>>1)
# Out:
# 1
# 7
# 6
# -6
# 10
# 2

# %% [markdown]
# #SETS HASHABILITY-
# #set elements must not change
#
# {1,"Python",(1,2,3)} --> allowed/valid set
# {[1,2,3]} --> not valid

# %% [markdown]
# #dictionary get method-
#
# .get()- is a safe method to read values from a dictionary
#
# it avoids errors when key is missing
#
# syntax-
# dictionary_name.get(key,default_value)

# %%
student={"name":"Alex","age":22}
print(student.get("marks"))
print("hello")
print(student.get("marks",0))
# Out:
# None
# hello
# 0

# %%
#obtaining unique values using set method
data=[1,2,3,4,3,3,2,2]
data1=set(data)
print(data1)
# Out:
# {1, 2, 3, 4}

# %%
#finding common customers in both regions using set operations
regionA = {"Alice", "Bob", "Charlie"}
regionB = {"Bob", "Diana", "Eve"}
print(regionA.intersection(regionB))
# Out:
# {'Bob'}

# %%
#String methods
text="python programming"
text1=text.upper()
print(text1)
text2="PYTHON PROGRAMMING"
text3=text2.lower()
print(text3)
print(text.title())
print(text.capitalize())
text4="     hello   "
print(text4.strip())
print(text4.lstrip())
print(text4.rstrip())
text5="Python is easy"
words=text5.split()
print(words)
date="wo:rdsletters:mobile:bottle"
print(date.split(":"))   
words=["Python","is","fun"]
sentence="#".join(words)
print(sentence)
# Out:
# PYTHON PROGRAMMING
# python programming
# Python Programming
# Python programming
# hello
# hello
#      hello
# ['Python', 'is', 'easy']
# ['wo', 'rdsletters', 'mobile', 'bottle']
# Python#is#fun

# %%
#Finding and replacing

text="python programming"
print(text.find("prog"))   #find position of substring, returns index if found 
print(text.find("ko"))     #if not found returns -1
text="i like python"
print(text.replace("python","mango"))
# Out:
# 7
# -1
# i like mango

# %%
#Checking content

text="Python"
print(text.startswith("Py"))
print(text.endswith("on"))
print(text.isalpha())   #is the string only letters
print(text.isdigit())  #is the string only digits
print(text.isalnum()) #is the string consisting of both alphabets and numbers

#length and counting

text="Python"
print(len(text))
text2="banana"
print(text2.count("a"))
# Out:
# True
# True
# True
# False
# True
# 6
# 3

# %%
#Checking membership (in,not in)
text3="Python"
print("Py" in text)
print("java" not in text)
# Out:
# True
# True
